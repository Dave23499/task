# %%
import os
import mysql.connector
from mysql.connector import Error
import webbrowser

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="W@rmachin3rox"
)

print(mydb)

# %%
mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('bincomphptest',)
# ('information_schema',)
# ('mini_supermarket',)
# ('mysql',)
# ('performance_schema',)
# ('sales_mgt',)
# ('school_admin',)
# ('sys',)

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="W@rmachin3rox",
  database="bincomphptest"
)

# %%
def get_table_data(mydb, table_name, header_row = None):
    select_query = f"SELECT * FROM {table_name}"
    cursor = mydb.cursor()
    cursor.execute(select_query)
    result = cursor.fetchall()

    column_names = [desc[0] for desc in cursor.description]

    results = []

    if header_row is not None:
        results.append(header_row)


    for row in result:
        results.append([str(value) for value in row])

    return results

# %%
table_name = "announced_pu_results"
header_row = ["<tr><td>result_id</td><td>lga_name</td><td>party_abbreviation</td><td>party_score</td><td>entered_by_user</td><td>date_entered</td><td>user_ip_address</td></tr>"]

table_data = get_table_data(mydb, table_name, header_row)
table_data
# Out:
# [['<tr><td>result_id</td><td>lga_name</td><td>party_abbreviation</td><td>party_score</td><td>entered_by_user</td><td>date_entered</td><td>user_ip_address</td></tr>'],
#  ['111', '8', 'PDP', '802', 'Bose', '2011-04-26 15:44:03', '192.168.1.101'],
#  ['112', '8', 'DPP', '719', 'Bose', '2011-04-26 15:44:03', '192.168.1.101'],
#  ['113', '8', 'ACN', '416', 'Bose', '2011-04-26 15:44:03', '192.168.1.101'],
#  ['114', '8', 'PPA', '939', 'Bose', '2011-04-26 15:44:03', '192.168.1.101'],
#  ['115', '8', 'CDC', '394', 'Bose', '2011-04-26 15:44:03', '192.168.1.101'],
#  ['116', '8', 'JP', '99', 'Bose', '2011-04-26 15:44:03', '192.168.1.101'],
#  ['117',
#   '9',
#   'PDP',
#   '285',
#   'Joseph Ogurume',
#   '2011-04-26 16:20:49',
#   '192.168.1.101'],
#  ['118',
#   '9',
#   'DPP',
#   '1254',
#   'Joseph Ogurume',
#   '2011-04-26 16:20:49',
#   '192.168.1.101'],
#  ['119',
#   '9',
#   'ACN',
#   '1032',
#   'Joseph Ogurume',
#   '2011-04-26 16:20:49',
#   '192.168.1.101'],
#  ['120',
# ...

# %%
contents = '''<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
<html>
<head>
<meta content="text/html; charset=ISO-8859-1"
http-equiv="content-type">
<title>Python Webbrowser</title>
</head>
<body>
<table>
# %s
</table>
</body>
</html>
'''%(table_data)

# %%
filename = 'web.html'

def main(contents, filename):
    output = open(filename,"w")
    output.write(contents)
    output.close()

main(contents, filename)    
webbrowser.open(filename)
# Out:
# True

# %%
get_result = """SELECT * FROM announced_pu_results"""
cursor = mydb.cursor()
cursor.execute(get_result)
result = cursor.fetchall()
print(len(result))
# Out:
# 150
